# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df = np.loadtxt('banana_DDPG_small.csv', delimiter=',')

# %%
plt.plot(df[:,0], df[:,1], 'o', alpha=0.1)
plt.savefig('banana_DDPG_small.png', dpi=600)
